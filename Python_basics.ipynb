# %% [markdown]
# # Python Einführung
# ## Erste Einweisung
# *kursiv* **fett** ***fett_u-kursiv***

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("something")
# Out:
# something

# %%
# Variablen und Wertzuweisung
name = "Lovelace"

# %%
print (name)
# Out:
# Lovelace

# %%
name
# Out:
# 'Lovelace'

# %%
age = 73

# %%
print(age)
# Out:
# 73

# %%
size = 1.7123

# %%
print(size)
# Out:
# 1.7123

# %%
knows_math = True

# %%
print(knows_math)
# Out:
# True

# %%
likes_garding = False

# %%
print(likes_garding)
# Out:
# False

# %%
type(name)
# Out:
# str

# %%
# Datentyp von likes_gardening und size

# %%
type(likes_garding)
# Out:
# bool

# %%
type(size)
# Out:
# float

# %% [markdown]
# ## Operatoren

# %%
5+5
# Out:
# 10

# %%
10 * age
# Out:
# 730

# %%
name + name
# Out:
# 'LovelaceLovelace'

# %%
name * 10
# Out:
# 'LovelaceLovelaceLovelaceLovelaceLovelaceLovelaceLovelaceLovelaceLovelaceLovelace'

# %%
name + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-eb654c50a077> in <module>
# ----> 1 name + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
name + "10"
# Out:
# 'Lovelace10'

# %%
name + str(10)
# Out:
# 'Lovelace10'

# %%
size / age
# Out:
# 0.023456164383561642

# %%
type(size/age)
# Out:
# float

# %%
int("10")
# Out:
# 10

# %%
type(10)
# Out:
# int

# %%
len(name)
# Out:
# 8

# %%
name.upper()
# Out:
# 'LOVELACE'

# %%
name
# Out:
# 'Lovelace'

# %%
name_up = name.upper

# %%
name_up
# Out:
# <function str.upper()>

# %%
print(name_up)
# Out:
# <built-in method upper of str object at 0x0000017A4239E2B0>

# %%
name = name.upper()

# %%
print(name_up)
# Out:
# <built-in method upper of str object at 0x0000017A4239E2B0>

# %%
name2 = Love
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-4c75292245fa> in <module>
# ----> 1 name2 = Love
#
# NameError: name 'Love' is not defined

# %%
name2 = "Test"

# %%
name2
# Out:
# 'Test'

# %%
names = ["Lovelace", "Darwin", "Curie", "Hawking"]

# %%
type(names)
# Out:
# list

# %%
names[2]
# Out:
# 'Curie'

# %%
authors_and_birthyears = {"Lovelace":1882,
                         "Darwin":1809,
                         "Curie:"?",
                          "Hawking":1942}
# Out:
#   File "<ipython-input-43-66c6412e41c5>", line 3
#     "Curie:"?",
#             ^
# SyntaxError: invalid syntax

# %%
authors_and_birthyears = {"Lovelace":1882,
                         "Darwin":1809,
                         "Curie":7,
                          "Hawking":1942}

# %%
authors_and_birthyears["Darwin"]
# Out:
# 1809

# %% [markdown]
# ## For-Schleife

# %%
print(names)
# Out:
# ['Lovelace', 'Darwin', 'Curie', 'Hawking']

# %%
for person in names:
# Out:
#   File "<ipython-input-47-f0bb655e4dfa>", line 1
#     for person in names:
#                         ^
# SyntaxError: unexpected EOF while parsing

# %%
for person in names
# Out:
#   File "<ipython-input-48-235e5de583a4>", line 1
#     for person in names
#                        ^
# SyntaxError: invalid syntax

# %%
print(names)
# Out:
# ['Lovelace', 'Darwin', 'Curie', 'Hawking']

# %%
names.append("fügtNeuesElementHinzu")

# %%
print(names)
# Out:
# ['Lovelace', 'Darwin', 'Curie', 'Hawking', 'fügtNeuesElementHinzu', 'fügtNeuesElementHinzu']

# %%
names.remove
# Out:
# <function list.remove(value, /)>

# %% [markdown]
# ## Bedingte Anweisungen

# %%
temp = 20
if temp > 15:
    print(It's warm")
# Out:
#   File "<ipython-input-56-27aa29f62b2d>", line 3
#     print(It's warm")
#                      ^
# SyntaxError: EOL while scanning string literal

# %%
temp = 20
if temp > 15:
    print("It's warm")
# Out:
# It's warm

# %%
temp = 10
if temp > 15:
    print("It's warm")
else:
    print("It's cold")
# Out:
# It's cold

# %%
temp = 10
if temp > 25:
    print("It's hot")
elif >= 15:
    print("It's warm")
else:
    print("It's cold")
# Out:
#   File "<ipython-input-61-567b7e33a6b9>", line 4
#     elif >= 15:
#          ^
# SyntaxError: invalid syntax

# %%
temp = 10
if temp > 25:
    print("It's hot")
elif tem >= 15:
    print("It's warm")
else:
    print("It's cold")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-0e2192353a78> in <module>
#       2 if temp > 25:
#       3     print("It's hot")
# ----> 4 elif tem >= 15:
#       5     print("It's warm")
#       6 else:
#
# NameError: name 'tem' is not defined

# %%
temp = 10
if temp > 25:
    print("It's hot")
elif temp >= 15:
    print("It's warm")
else:
    print("It's cold")
# Out:
# It's cold

# %%
import os
print(os.path.abspath(os.getcwd()))
# Out:
# C:\Users\asteinert

# %%
! pip install pyppeteer

# %%
! pip install pyppeteer
