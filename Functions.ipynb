# %%
dirty_isbns = [
    " ISBN 978-1449369415 ", 
    "ISBN___978-1491946008 ",
    "ISBN 978-1593276034"]

# %%
def clean_isbn():
    isbns = " ISBN 978-1449369415 "
    print(isbn)

# %%
def clean_isbn():
    isbn = " ISBN 978-1449369415 "
    print(isbn)
    
clean_isbn()
# Out:
#  ISBN 978-1449369415

# %%
def clean_isbn():
    isbn = " ISBN 978-1449369415 " 
clean_isbn()

# %%
clean_isbn()

# %%
def clean_isbn():
    isbn = " ISBN 978-1449369415 "
    isbn = isbn.replace("ISBN", "")
    isbn = isbn.strip()
    print(isbn)
    
clean_isbn()
# Out:
# 978-1449369415

# %%
def clean_isbn(isbn):
    isbn = isbn.replace("ISBN", "")
    isbn = isbn.strip()
    print(isbn)
    
clean_isbn(" ISBN 978-1449369415 ")
# Out:
# 978-1449369415

# %%
def clean_isbn(isbn):
    isbn = isbn.replace("ISBN", "")
    isbn = isbn.strip()
    return isbn
    
clean_isbn(" ISBN 978-1449369415 ")
# Out:
# '978-1449369415'

# %%
def clean_isbn(isbn):
    isbn = isbn.replace("ISBN", "")
    isbn = isbn.strip()
    return isbn
    
cleaned_isbn = clean_isbn(" ISBN 978-1449369415 ")

# %%
print("Saubere ISBN: " + cleaned_isbn)
# Out:
# Saubere ISBN: 978-1449369415

# %%
clean_isbn(xxx ISBN 1255)
# Out:
#   File "<ipython-input-12-7636da23b8b2>", line 1
#     clean_isbn(xxx ISBN 1255)
#                    ^
# SyntaxError: invalid syntax

# %%
clean_isbn("xxx ISBN 1255")
# Out:
# 'xxx  1255'

# %%
for dirty_isbn in dirty_isbns:
    print(clean_isbn(dirty_isbn))
# Out:
# 978-1449369415
# ___978-1491946008
# 978-1593276034

# %%
for dirty_isbn in dirty_isbns:
    print("Cleaned: " + clean_isbn(dirty_isbn))
# Out:
# Cleaned: 978-1449369415
# Cleaned: ___978-1491946008
# Cleaned: 978-1593276034
